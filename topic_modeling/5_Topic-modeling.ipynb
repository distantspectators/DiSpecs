# %% [markdown]
# # Topics – Easy Topic Modeling in Python
#
#
# This notebook was adapted from <a href="https://github.com/DARIAH-DE/Topics"><i>Topics</i> (DARIAH-DE)</a> notebook IntroducingMallet.ipynb for the project DiSpecs. <br>
# The original markdown text is kept and highlighted in italic. The section Visualization is separated into a new notebook (6_Topic-visualization).
#
# <i>The text mining technique **Topic Modeling** has become a popular statistical method for clustering documents. This [Jupyter notebook](http://jupyter.org/) introduces a step-by-step workflow, basically containing data preprocessing, the actual topic modeling using **latent Dirichlet allocation** (LDA), which learns the relationships between words, topics, and documents, as well as some interactive visualizations to explore the model.
#
# LDA, introduced in the context of text analysis in [2003](http://www.jmlr.org/papers/volume3/blei03a/blei03a.pdf), is an instance of a more general class of models called **mixed-membership models**. Involving a number of distributions and parameters, the topic model is typically performed using [Gibbs sampling](https://en.wikipedia.org/wiki/Gibbs_sampling) with conjugate priors and is purely based on word frequencies.
#
# There have been written numerous introductions to topic modeling for humanists (e.g. [this one](http://scottbot.net/topic-modeling-for-humanists-a-guided-tour/)), which provide another level of detail regarding its technical and epistemic properties.
#
# For this workflow, you will need a corpus (a set of texts) as plain text (`.txt`) or [TEI XML](http://www.tei-c.org/index.xml) (`.xml`). Using the `dariah_topics` package, you also have the ability to process the output of [DARIAH-DKPro-Wrapper](https://github.com/DARIAH-DE/DARIAH-DKPro-Wrapper), a command-line tool for *natural language processing*.
#
# Topic modeling works best with very large corpora. The [TextGrid Repository](https://textgridrep.org/) is a great place to start searching for text data. Anyway, to demonstrate the technique, we provide one small text collection in the folder `grenzboten_sample` containing 15 diary excerpts, as well as 15 war diary excerpts, which appeared in *Die Grenzboten*, a German newspaper of the late 19th and early 20th century.
#
# **Of course, you can work with your own corpus in this notebook.**
#
# We're relying on the LDA implementation by [Andrew McCallum](https://people.cs.umass.edu/~mccallum/), called [MALLET](http://mallet.cs.umass.edu/topics.php), which is known to be very robust. Aside from that, we provide two more Jupyter notebooks:
#
# * [IntroducingGensim](IntroducingGensim.ipynb), using LDA by [Gensim](https://radimrehurek.com/project/gensim/), which is attractive because of its multi-core support.
# * [IntroducingLda](IntroducingLda.ipynb), using LDA by [lda](http://pythonhosted.org/lda/index.html), which is very lightweight.
#
# For more information in general, have a look at the [documentation](http://dev.digital-humanities.de/ci/job/DARIAH-Topics/doclinks/1/).</i>

# %% [markdown]
# ## First step: Installing dependencies
#
# <i>To work within this Jupyter notebook, you will have to import the `dariah_topics` library. As you do, `dariah_topics` also imports a couple of external libraries, which have to be installed first. `pip` is the preferred installer program in Python. Starting with Python 3.4, it is included by default with the Python binary installers. If you are interested in `pip`, have a look at [this website](https://docs.python.org/3/installing/index.html).
#
# To install the `dariah_topics` library with all dependencies, open your commandline, go with `cd` to the folder `Topics` and run:
#
# ```
# pip install -r requirements.txt
# ```
#
# Alternatively, you can do:
#
# ```
# python setup.py install
# ```
#
# If you get any errors or are not able to install *all* dependencies properly, try [Stack Overflow](https://stackoverflow.com/questions/tagged/pip) for troubleshooting or create a new issue on our [GitHub page](https://github.com/DARIAH-DE/Topics).
#
# **Important**: If you are on macOS or Linux, you will have to use `pip3` and `python3`.</i>

# %% [markdown]
# ### Some final words
# <i>As you probably already know, code has to be written in the grey cells. You execute a cell by clicking the **Run**-button (or **Ctrl + Enter**). If you want to run all cells of the notebook at once, click **Cell > Run All** or **Kernel > Restart & Run All** respectively, if you want to restart the Python kernel first. On the left side of an (unexecuted) cell stands `In [ ]:`. The empty bracket means, that the cell hasn't been executed yet. By clicking **Run**, a star appears in the brackets (`In [*]:`), which means the process is running. In most cases, you won't see that star, because your computer is faster than your eyes. You can execute only one cell at once, all following executions will be in the waiting line. If the process of a cell is done, a number appears in the brackets (`In [1]:`).</i>

# %% [markdown]
# ## Starting with topic modeling!
#
# <i>Execute the following cell to import modules from the `dariah_topics` library.</i>

# %%
from cophi_toolbox import preprocessing
from dariah_topics import utils
from dariah_topics import postprocessing
from dariah_topics import visualization

# %% [markdown]
# <i>Furthermore, we will need some additional functions from external libraries.</i>

# %%
import metadata_toolbox.utils as metadata
import pandas as pd
from pathlib import Path

# %% [markdown]
# <i>Let's not pay heed to any warnings right now and execute the following cell.</i>

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# We will import a few more packages for DiSpecs:

# %%
import os
import numpy as np
from collections import Counter
import pickle
from datetime import datetime

# %%
# a datetime object containing current date and time
now = datetime.now()

dt_string = now.strftime("%Y%m%d-%H%M")
print("date and time =", dt_string)
# Out:
# date and time = 20210520-1117

# %% [markdown]
# ## 1. Preprocessing

# %% [markdown]
# ### 1.1. Reading a corpus of documents

# %% [markdown]
# #### Defining the path to the corpus folder
#
# <i>In the present example code, we are using the 30 diary excerpts from the folder `grenzboten`. To use your own corpus, change the path accordingly.</i>

# %%
#data = 'Y:/data/projekte/dispecs/TopicModeling' 
#path_to_corpus = Path(data, 'dispecs_es')

# Path variables
data = 'Y:/data/projekte/dispecs/TopicModeling' 
language = 'it'
path_to_corpus = Path(data, 'dispecs_'+language+'_paragr')

# %% [markdown]
# #### Specifying the pattern of filenames for metadata extraction
#
# <i>You have the ability to extract metadata from the filenames. For instance, if your textfiles look like:
#
# ```
# goethe_1816_stella.txt
# ```
#
# the pattern would look like this:
#
# ```
# {author}_{year}_{title}
# ```
#
# So, let's try this for the example corpus.</i>
#
#
# Change the pattern according to your file names.

# %%
pattern = '{year}_{periodical}_{author}_{volume}_{issue}_{id}_{chunk}' #_{chunk}

# %% [markdown]
# #### Accessing file paths and metadata
# <i>We begin by creating a list of all the documents in the folder specified above. That list will tell the function `preprocessing.read_files` (see below) which text documents to read. Furthermore, based on filenames we can create some metadata, e.g. author and title.<i>

# %%
meta = pd.concat([metadata.fname2metadata(str(path), pattern=pattern) for path in path_to_corpus.glob('*.txt')])
meta[:5] # by adding '[:5]' to the variable, only the first 5 elements will be printed
# Out:
#                                                     year  \
# Y:\data\projekte\dispecs\TopicModeling\dispecs_...  1727
# Y:\data\projekte\dispecs\TopicModeling\dispecs_...  1727
# Y:\data\projekte\dispecs\TopicModeling\dispecs_...  1727
# Y:\data\projekte\dispecs\TopicModeling\dispecs_...  1727
# Y:\data\projekte\dispecs\TopicModeling\dispecs_...  1727
#
#                                                                periodical  \
# Y:\data\projekte\dispecs\TopicModeling\dispecs_...  Il-Filosofo-alla-Moda
# Y:\data\projekte\dispecs\TopicModeling\dispecs_...  Il-Filosofo-alla-Moda
# Y:\data\projekte\dispecs\TopicModeling\dispecs_...  Il-Filosofo-alla-Moda
# Y:\data\projekte\dispecs\TopicModeling\dispecs_...  Il-Filosofo-alla-Moda
# Y:\data\projekte\dispecs\TopicModeling\dispecs_...  Il-Filosofo-alla-Moda
#
#                                                              author volume  \
# Y:\data\projekte\dispecs\TopicModeling\dispecs_...  Cesare-Frasponi  Vol-1
# Y:\data\projekte\dispecs\TopicModeling\dispecs_...  Cesare-Frasponi  Vol-2
# Y:\data\projekte\dispecs\TopicModeling\dispecs_...  Cesare-Frasponi  Vol-2
# Y:\data\projekte\dispecs\TopicModeling\dispecs_...  Cesare-Frasponi  Vol-2
# Y:\data\projekte\dispecs\TopicModeling\dispecs_...  Cesare-Frasponi  Vol-2
#
#                                                       issue       id chunk
# Y:\data\projekte\dispecs\TopicModeling\dispecs_...   Nr-000  09A-399  0000
# Y:\data\projekte\dispecs\TopicModeling\dispecs_...  Nr-0651  09A-398  0000
# Y:\data\projekte\dispecs\TopicModeling\dispecs_...   Nr-101  096-282  0000
# Y:\data\projekte\dispecs\TopicModeling\dispecs_...   Nr-101  096-282  0001
# Y:\data\projekte\dispecs\TopicModeling\dispecs_...   Nr-101  096-282  0002

# %% [markdown]
# Depending on which language you are analyzing, you might notice different language variants of the word "anonymous" in the column "author". We can correct this in the data frame by replacing the respective string with "Anonymous".

# %%
str_to_replace = [r'\bAnonymus\b', r'\bAnonym\b', r'\bAnonyme\b', r'\bAnónimo\b']
for string in str_to_replace:
    meta['author'] = meta['author'].str.replace(string, "Anonymous", regex=True)

# %% [markdown]
# You can now take a look at what authors and periodicals occur in your corpus and with how many issues they are represented.

# %%
meta.groupby('author')['id'].nunique()
# Out:
# author
# Anonymous-(Eliza-Haywood)          7
# Antonio-Piazza                   245
# Cesare-Frasponi                  393
# Francesco-Anselmi                 30
# Francesco-Grassi                  34
# Gasparo-Gozzi                    248
# Gioseffa-Cornoldi-Caminer         36
# Giovanni-Ferri-di-S.-Costante    261
# Giuseppe-Baretti                  33
# Luca-Magnanima                    39
# Pietro-und-Alessandro-Verri       18
# Name: id, dtype: int64

# %%
meta.groupby('periodical')['id'].nunique()
# Out:
# periodical
# Gazzetta-urbana-veneta                         245
# Gazzetta-veneta                                103
# Gli-Osservatori-veneti                          41
# Il-Caffè                                        18
# Il-Filosofo-alla-Moda                          393
# Il-Socrate-veneto                               30
# La-Frusta-Letteraria-di-Aristarco-Scannabue     33
# La-Spettatrice                                   7
# La-donna-galante-ed-erudita                     36
# Lo-Spettatore-italiano                         261
# Lo-Spettatore-italiano-piemontese               34
# L’Osservatore-veneto                           104
# Osservatore-toscano                             39
# Name: id, dtype: int64

# %% [markdown]
# #### Read listed documents from folder

# %%
corpus = list(preprocessing.read_files(meta.index))
corpus[1][:4000] # printing the first x number of characters of the first document
# Out:
# 'Eccovi Leggitore benigno un fasciare d altri Fogli volanti legare anch esso come il primo in formare di Libro se volere divertirvi figuratevi di entrare in una selva composto da una varietà singolare di Alberi e ritroverete che formare tra di loro una confusione gradita. Si essere piantati o inseriti di giorno in giorno a misurare che capitare alla mano. Non vi sorprendere per tangere se alcun di quelli che produrre la medesimo specie di frutti vi essere posto frammischiare con altri in qualche distanza. Vi accaderà mi lusingo con qualche piacer il passare da una Pianta di Peri ad una di Noci da questo ad un Giregio indo ad Giugiolo ad una Pigna ad un Pomo ad un Nespolo ad un Cotogno e poscia d incontrarvi qualche volto in un altra pianto di Peri di Po mi o di Ceregj però sempre con differire innesto con distinto figura con diverso colore e con variare sapore. Passegiate con attenzione osservare a vostro bell aggio e divertitevi. Vi dare la permissione di raccogliere quanto frutto volere per vostro uso ma incaricare la vostro anima se ne pigliare per regalarne quello che non vi essere Amici. ### N.N. ### ###'

# %% [markdown]
# <i>Your `corpus` contains as much elements (`documents`) as texts in your corpus are. Each element of `corpus` is a list containing exactly one element, the text itself as one single string including all whitespaces and punctuations:
#
# ```
# [['This is the content of your first document.'],
#  ['This is the content of your second document.'],
#  ...
#  ['This is the content of your last document.']]
# ```<i>

# %% [markdown]
# Check the length of your corpus:

# %%
len(corpus)
# Out:
# 5363

# %% [markdown]
# ### 1.3. Tokenize corpus
# <i>Now, your `documents` in `corpus` will be tokenized. Tokenization is the task of cutting a stream of characters into linguistic units, simply words or, more precisely, tokens. The tokenize function `dariah_topics` provides is a simple Unicode tokenizer. Depending on the corpus, it might be useful to use an external tokenizer function, or even develop your own, since its efficiency varies with language, epoch and text type.<i>

# %%
tokenized_corpus = [list(preprocessing.tokenize(document)) for document in corpus]

# %% [markdown]
# <i>At this point, each `document` is represented by a list of separate token strings. As above, have a look at the first document (which has the index `0` as Python starts counting at 0) and show its first 14 words/tokens (that have the indices `0:13` accordingly).<i>

# %%
tokenized_corpus[0]
# Out:
# ['non',
#  'vi',
#  'essere',
#  'forse',
#  'mai',
#  'stare',
#  'verun',
#  'opra',
#  'nè',
#  'antica',
#  'nè',
#  'moderna',
#  'che',
#  'avere',
#  'fare',
#  'tangere',
#  'strepitare',
#  'nel',
#  'paese',
#  'dov',
#  'nata',
#  'di',
#  'cui',
#  'siansi',
#  'esitare',
#  'tanto',
#  'esemplari',
#  'come',
#  'questo',
#  'del',
#  'spettatore',
#  'da',
#  'cui',
#  'si',
#  'essere',
#  'ricavare',
#  'il',
#  'filosofo',
#  'alla',
#  'moda',
#  'tutti',
#  'li',
#  'discorsi',
#  'che',
#  'la',
#  'compongono',
#  'orare',
#  'intitolare',
#  'lezioni',
#  'comparire',
#  'da',
#  'principiare',
#  'ad',
#  'un',
#  'ad',
#  'un',
#  'in',
#  'qualità',
#  'di',
#  'fogli',
#  'volanti',
#  'in',
#  'figurare',
#  'di',
#  'gazette',
#  'se',
#  'ne',
#  'essere',
#  'venduto',
#  'fino',
#  'ventimila',
#  'al',
#  'giorno',
#  'se',
#  'ne',
#  'essere',
#  'di',
#  'molto',
#  'fare',
#  'in',
#  'poco',
#  'anno',
#  'quattro',
#  'edizioni',
#  'francesi',
#  'tali',
#  'discorso',
#  'non',
#  'essere',
#  'fatturare',
#  'un',
#  'solo',
#  'come',
#  'con',
#  'evidenza',
#  'vi',
#  'fare',
#  'palese',
#  'la',
#  'varietà',
#  'della',
#  'frase',
#  've',
#  'ne',
#  'essere',
#  'alcuni',
#  'che',
#  'non',
#  'si',
#  'essere',
#  'potere',
#  'addatare',
#  'nostro',
#  'costumi',
#  'perciò',
#  'si',
#  'essere',
#  'lasciati',
#  'vi',
#  'essere',
#  'accomodati',
#  'non',
#  'si',
#  'esporre',
#  'il',
#  'motivare',
#  'di',
#  'questo',
#  'applicazione',
#  'da',
#  'voi',
#  'medesimo',
#  'il',
#  'vedrete',
#  'cioè',
#  'la',
#  'pubblico',
#  'utilità',
#  'si',
#  'tacere',
#  'puro',
#  'il',
#  'motivare',
#  'di',
#  'cambiare',
#  'il',
#  'titoli',
#  'chi',
#  'si',
#  'dare',
#  'la',
#  'penare',
#  'di',
#  'farvi',
#  'maturo',
#  'riflessione',
#  'ne',
#  'conoscerà',
#  'se',
#  'non',
#  'altro',
#  'la',
#  'grande',
#  'proprietà',
#  'bastare',
#  'esaminare',
#  'che',
#  'opra',
#  'fù',
#  'da',
#  'principiare',
#  'intraprendere',
#  'con',
#  'misura',
#  'molto',
#  'ristretto',
#  'di',
#  'quelle',
#  'che',
#  'in',
#  'progresso',
#  'di',
#  'tempo',
#  'si',
#  'essere',
#  'allargate',
#  'per',
#  'non',
#  'diro',
#  'variate',
#  'la',
#  'società',
#  'de',
#  'motivati',
#  'scrittori',
#  'anonimo',
#  'si',
#  'non',
#  'sò',
#  'per',
#  'quale',
#  'cagione',
#  'disciolta',
#  'si',
#  'che',
#  'tutto',
#  'il',
#  'lavoriero',
#  'che',
#  'fea',
#  'mostrare',
#  'di',
#  'perpetuo',
#  'si',
#  'essere',
#  'terminare',
#  'in',
#  'poco',
#  'tometti',
#  'se',
#  'però',
#  'concertato',
#  'un',
#  'altra',
#  'di',
#  'modesti',
#  'letterati',
#  'soggetti',
#  'che',
#  'di',
#  'già',
#  'impiegare',
#  'qualche',
#  'orare',
#  'del',
#  'giorno',
#  'fino',
#  'di',
#  'proseguire',
#  'la',
#  'giovevole',
#  'opra',
#  'si',
#  'che',
#  'vedransi',
#  'in',
#  'breve',
#  'de',
#  'fogli',
#  'volanti',
#  'per',
#  'indo',
#  'addunarli',
#  'in',
#  'tomi']

# %% [markdown]
# ### 1.4 Create a document-term matrix
#
# <i>The LDA topic model is based on a [document-term matrix](https://en.wikipedia.org/wiki/Document-term_matrix) of the corpus. To improve performance in large corpora, the matrix describes the frequency of terms that occur in the collection. In a document-term matrix, rows correspond to documents in the collection and columns correspond to terms.</i>
#
# __Use only one of the following two versions for creating the matrix.__<br>
# Change the meta argument according to the pieces of information you want to keep in your matrix. Important: Each filename still needs to stay distinctive, so you should include a distinctive feature, like for example the ID.

# %% [markdown]
# #### 1.4.1 Large corpus matrix
#
# <i>If you have a very large corpus, create a document-term matrix designed for large corpora.<i>

# %%
document_term_matrix, document_ids, type_ids = preprocessing.create_document_term_matrix(tokenized_corpus,
                                                                                         meta['author']+'_'+meta['periodical']+'_' + meta['volume']+'_' + meta['issue']+'_'+meta['id']+'_'+meta['chunk'],
                                                                                         large_corpus=True) #+'_'+meta['chunk']
(document_term_matrix, document_ids, type_ids)[:5]
# Out:
# (                      0
#  document_id type_id
#  1           25246     5
#              42528     1
#              80412    11
#              7802      1
#              33924    18
#              73926     1
#              25549    11
#              73683     1
#              67679     1
#              41769     1
#              41709     1
#              51523     3
#              107604    1
#              69706     5
#              12696     1
#              83816     1
#              25745     1
#              11449     7
#              76967     1
#              52860    10
#              78536     4
#              64237     1
#              53153     1
#              84741     3
#              98357    11
#              54835     5
#              20188     4
#              53109     2
#              54111     3
#              7824      1
#  ...                  ..
#  5363        100224    1
#              71365     1
#              78807     1
#              75730     1
#              6588      1
#              75527     1
#              88481     1
#              92559     1
#              70989     1
#              99301     1
#              22752     1
#              97444     1
#              32634     1
#              38464     1
#              13490     1
#              62447     1
#              47708     1
#              59619     1
#              71730     1
#              70465     2
#              21278     1
#              22507     1
#              34495     1
#              48396     1
#              43720     1
#              3304      1
#              77802     1
#              100730    1
#              58496     1
#              38656     1
#
#  [1630108 rows x 1 columns],
#  {'Antonio-Piazza_Gazzetta-urbana-veneta_Vol-4_Nr-042_4456_0002': 1,
#   'Gasparo-Gozzi_Gazzetta-veneta_Vol-1_Nr-104_6359_0000': 2,
#   'Giovanni-Ferri-di-S.-Costante_Lo-Spettatore-italiano_Vol-4_Nr-46_5395_0001': 3,
#   'Giuseppe-Baretti_La-Frusta-Letteraria-di-Aristarco-Scannabue_Vol-5_Nr-24_117-1172_0003': 4,
#   'Antonio-Piazza_Gazzetta-urbana-veneta_Vol-4_Nr-004_4418_0002': 5,
#   'Gasparo-Gozzi_L’Osservatore-veneto_Vol-1_Nr-011_099-364_0002': 6,
#   'Antonio-Piazza_Gazzetta-urbana-veneta_Vol-4_Nr-104_4515_0005': 7,
#   'Cesare-Frasponi_Il-Filosofo-alla-Moda_Vol-2_Nr-113_096-294_0000': 8,
#   'Antonio-Piazza_Gazzetta-urbana-veneta_Vol-4_Nr-047_4461_0003': 9,
#   'Giovanni-Ferri-di-S.-Costante_Lo-Spettatore-italiano_Vol-2_Nr

#   'Gasparo-Gozzi_L’Osservatore-veneto_Vol-1_Nr-090_103-531_0001': 589,
#   'Cesare-Frasponi_Il-Filosofo-alla-Moda_Vol-4_Nr-205_7038_0000': 590,
#   'Antonio-Piazza_Gazzetta-urbana-veneta_Vol-4_Nr-074_4488_0000': 591,
#   'Giovanni-Ferri-di-S.-Costante_Lo-Spettatore-italiano_Vol-3_Nr-40_117-1023_0001': 592,
#   'Cesare-Frasponi_Il-Filosofo-alla-Moda_Vol-5_Nr-308_7508_0000': 593,
#   'Giovanni-Ferri-di-S.-Costante_Lo-Spettatore-italiano_Vol-4_Nr-40_117-1118_0001': 594,
#   'Cesare-Frasponi_Il-Filosofo-alla-Moda_Vol-1_Nr-059_092-219_0000': 595,
#   'Anonymous-(Eliza-Haywood)_La-Spettatrice_Vol-1_Nr-02_3838_0012': 596,
#   'Gasparo-Gozzi_L’Osservatore-veneto_Vol-1_Nr-028_103-468_0002': 597,
#   'Antonio-Piazza_Gazzetta-urbana-veneta_Vol-3_Nr-082_4081_0000': 598,
#   'Gasparo-Gozzi_L’Osservatore-veneto_Vol-1_Nr-002_099-355_0001': 599,
#   'Luca-Magnanima_Osservatore-toscano_Vol-1_Nr-09_5414_0002': 600,
#   'Antonio-Piazza_Gazzetta-urbana-veneta_Vol-4_Nr-059_4473_0007': 601,
#   'Antonio-Piazza_Gazzetta-urbana-veneta_Vol-4_Nr-072_4486_0005': 602,
#   'Antonio-Piazza_Gazzetta-urbana-veneta_Vol-3_Nr-078_4077_0001': 603,
#   'Gasparo-Gozzi_Gazzetta-veneta_Vol-1_Nr-022_3479_0001': 604,
#   'Gasparo-Gozzi_L’Osservatore-veneto_Vol-1_Nr-065_103-506_0002': 605,
#   'Giovanni-Ferri-di-S.-Costante_Lo-Spettatore-italiano_Vol-2_Nr-60_117-960_0000': 606,
#   'Gasparo-Gozzi_Gazzetta-veneta_Vol-1_Nr-083_5568_0000': 607,
#   'Giovanni-Ferri-di-S.-Costante_Lo-Spettatore-italiano_Vol-3_Nr-03_117-986_0001': 608,
#   'Pietro-und-Alessandro-Verri_Il-Caffè_Vol-1_Nr-10_6744_0004': 609,
#   'Antonio-Piazza_Gazzetta-urbana-veneta_Vol-4_Nr-045_4459_0001': 610,
#   'Antonio-Piazza_Gazzetta-urbana-veneta_Vol-3_Nr-085_4084_0005': 611,
#   'Giovanni-Ferri-di-S.-Costante_Lo-Spettatore-italiano_Vol-1_Nr-06_115-881_0005': 612,
#   'Gasparo-Gozzi_Gazzetta-veneta_Vol-1_Nr-051_5536_0000': 613,
#   'Luca-Magnanima_Osservatore-toscano_Vol-1_Nr-07_5433_0001': 614,
#   'Gasparo-Gozzi_Gazzetta-veneta_Vol-1_Nr-066_5551_0001': 615,
#   'Gioseffa-Cornoldi-Caminer_La-donna-galante-ed-erudita_Vol-3_Nr-04_7442_0001': 616,
#   'Giuseppe-Baretti_La-Frusta-Letteraria-di-Aristarco-Scannabue_Vol-2_Nr-10_117-1158_0001': 617,
#   'Gasparo-Gozzi_L’Osservatore-veneto_Vol-1_Nr-041_103-481_0001': 618,
#   'Antonio-Piazza_Gazzetta-urbana-veneta_Vol-3_Nr-051_4050_0004': 619,
# ...
#   'vescovado': 188,
#   'praetoris': 189,
#   'indifferenza': 190,
#   'scorzi': 191,
#   'ribadisci': 192,
#   'congedarsi': 193,
#   'sconsolare': 194,
#   'ribboni': 195,
#   'rendesi': 196,
#   'abbandonarti': 197,
#   'criminale': 198,
#   'ordina': 199,
#   'tilotson': 200,
#   'capoletto': 201,
#   'accorsivi': 202,
#   'giustificativa': 203,
#   'melang': 204,
#   'upupa': 205,
#   'cimieri': 206,
#   'stabilendo': 207,
#   'cresippo': 208,
#   'miseramente': 209,
#   'favellano': 210,
#   'valendosi': 211,
#   'oneroso': 212,
#   'levantino': 213,
#   'rosseggiare': 214,
#   'svida': 215,
#   'tuttatrè': 216,
#   'maddal': 217,
#   'partecipa': 218,
#   'spedirvelo': 219,
#   'intrichi': 220,
#   'rinnovellava': 221,
#   'rappresentasi': 222,
#   'mescolanza': 223,
#   'fanatico': 224,
#   'tulipa': 225,
#   'traspiantarvi': 226,
#   'mansuetamente': 227,
#   'comperati': 228,
#   'alzala': 229,
#   'soffiano': 230,
#   'sparirono': 231,
#   'sovrastavano': 232,
#   'cantata': 233,
#   'piombarvi': 234,
#   'casal': 235,
#   'rinforzi': 236,
#   'sederle': 237,
#   'risoluti': 238,
#   'sapientemente': 239,
#   'acclamatione': 240,
#   'vergognata': 241,
#   'lazz': 242,
#   'satisfaremo': 243,
#   'tortorelle': 244,
#   'spinella': 245,
#   'avviandosi': 246,
#   'croceos': 247,
#   'apprestamento': 248,
#   'cappirciosi': 249,
#   'blockhead': 250,
#   'parrebbono': 251,
#   'sacramentare': 252,
#   'accingerai': 253,
#   'trasferirvi': 254,
#   'antiporta': 255,
#   'acerbissimo': 256,
#   'accettante': 257,
#   'rot': 258,
#   'sprovvisto': 259,
#   'paride': 260,
#   'pagherebbero': 261,
#   'campistron': 262,
#   'arringa': 263,
#   'caratterizzata': 264,
#   'præt': 265,
#   'colludrovich': 266,
#   'palladiana': 267,
#   'parlerovvi': 268,
#   'lanzenigo': 269,
#   'chiese': 270,
#   'cooptati': 271,
#   'antenati': 272,
#   'dispiacerebbemi': 273,
#   'fischer': 274,
#   'pretenderebbero': 275,
#   'rispetterai': 276,
#   'imbarcammo': 277,
#   'joas': 278,
#   'infermaria': 279,
#   'bigatti': 280,
#   'rifflesso': 281,
#   'benefiziate': 282,
#   'merebantur': 283,
#   'dipartano': 284,
#   'discacciate': 285,
#   'frizierio': 286,
#   'baldini': 287,
#   'annodarli': 288,
#   'smaltimento': 289,
#   'anellino': 290,
#   'ruscello': 291,
#   'avvidi': 292,
#   'explanat': 293,
#   'impiegare': 294,
#   'suscitant': 295,
#   'estirpata': 296,
#   'signorevoli': 297,
#   'fragile': 298,
#   'amministrino': 299,
#   'novantacinque': 300,
#   'oime': 301,
#   'anführungszeichen': 302,
#   'indovinare': 303,
#   'allevarvi': 304,
#   'pietoso': 305,
#   'muri': 306,
#   'tôrre': 307,
#   'suggestivo': 308,
#   'kings': 309,
#   'gambaroni': 310,
#   'dragontea': 311,
#   'infelice': 312,
#   'memorare': 313,
#   'nascen': 314,
#   'rinforzasi': 315,
#   'portavane': 316,
#   'considarabile': 317,
#   'incalzano': 318,
#   'confermarle': 319,
#   'gheno': 320,
#   'vanarella': 321,
#   'gragnuole': 322,
#   'negandomi': 323,
#   'pateticamente': 324,
#   'rimirarvi': 325,
#   'prescritti': 326,
#   'urta': 327,
#   'orzi': 328,
#   'naillac': 329,
#   'soccom': 330,
#   'morendo': 331,
#   'istudiato': 332,
#   'gabriello': 333,
#   'abbondoso': 334,
#   'baluganti': 335,
#   'angelopoli': 336,
#   'motteggia': 337,
#   'fantollino': 338,
#   'dimezzare': 339,
#   'attendrir': 340,
#   'riguardiamo': 341,
#   'cesti': 342,
#   'ingrandimento': 343,
#   'trinato': 344,
#   'ecatissa': 345,
#   'ricci': 346,
#   'dassi': 347,
#   'parruchiere': 348,
#   'volasse': 349,
#   'nuotasi': 350,
#   'tirarci': 351,
#   'escirono': 352,
#   'ricoverata': 353,
#   'elba': 354,
#   'bestiuole': 355,
#   'simigliare': 356,
#   'indemoniata': 357,
#   'rano': 358,
#   'frustare': 359,
#   'michelangioli': 360,
#   'estemporaneo': 361,
#   'cavendish': 362,
#   'mazzuchelli': 363,
#   'stupitissimi': 364,
#   'facti': 365,
#   'servidore': 366,
#   'soggezione': 367,
#   'vechio': 368,
#   'pannello': 369,
#   'prestasse': 370,
#   'importunava': 371,
#   'spadaria': 372,
#   'infiammagioni': 373,
#   'diró': 374,
#   'tabarro': 375,
#   'cherson': 376,
#   'bellarmino': 377,
#   'dolgonsi': 378,
#   'udì': 379,
#   'confiscata': 380,
#   'sutterfugi': 381,
#   'entrargli': 382,
#   'adduna': 383,
#   'estinzione': 384,
#   'dipinseli': 385,
#   'apprenderò': 386,
#   'citaremmo': 387,
#   'caprone': 388,
#   'mangiai': 389,
#   'soffrano': 390,
#   'agostin': 391,
#   'curarti': 392,
#   'stancheranno': 393,
#   'proverebbono': 394,
#   'difendersene': 395,
#   'successorem': 396,
#   'guastatore': 397,
#   'esagona': 398,
#   'lasciargli': 399,
#   'senta': 400,
#   'obducta': 401,
#   'sponde': 402,
#   'maledettissime': 403,
#   'dicʼegli': 404,
#   'stillate': 405,
#   'introdur': 406,
#   'deducendoli': 407,
#   'carnioni': 408,
#   'instrum': 409,
#   'siniscalco': 410,
#   'dimissoria': 411,
#   'sopravenne': 412,
#   'vezzosi': 413,
#   'valle': 414,
#   'azef': 415,
#   'profili': 416,
#   'lasciandone': 417,
#   'ripreso': 418,
#   'borini': 419,
#   'avesani': 420,
#   'approfittarsi': 421,
#   'istamperete': 422,
#   'sperto': 423,
#   'dalmatino': 424,
#   'testata': 425,
#   'cœur': 426,
#   'pettegolismo': 427,
#   'riasumere': 428,
#   'tosse': 429,
#   'arcaismo': 430,
#   'randellare': 431,
#   'comperato': 432,
#   'distendere': 433,
#   'disingannato': 434,
#   'guardasse': 435,
#   'delicatura': 436,
#   'divino': 437,
#   'saccocce': 438,
#   'vocali': 439,
#   'trojani': 440,
#   'amstardam': 441,
#   'dolesse': 442,
#   'preterito': 443,
#   'antonius': 444,
#   'intestare': 445,
#   'ampollosa': 446,
#   'iun': 447,
#   'paghisi': 448,
#   'letamaio': 449,
#   'iscorcio': 450,
#   'divoratore': 451,
#   'antimonio': 452,
#   'marchisi': 453,
#   'cute': 454,
#   'svantaggiosa': 455,
#   'bastare': 456,
#   'meravigliano': 457,
#   'rallegrarvi': 458,
#   'joan': 459,
#   'invidiarono': 460,
#   'accresecere': 461,
#   'scarnato': 462,
#   'inerendo': 463,
#   'tartassarmi': 464,
#   'terrra': 465,
#   'silfi': 466,
#   'liruti': 467,
#   'accendeala': 468,
#   'servonsi': 469,
#   'separare': 470,
#   'baffi': 471,
#   'allorquando': 472,
#   'concordano': 473,
#   'furfanterie': 474,
#   'somministrargli': 475,
#   'isvilupargli': 476,
#   'aggravandosi': 477,
#   'apperture': 478,
#   'interessino': 479,
#   'arcadica': 480,
#   'frequenza': 481,
#   'ragiòne': 482,
#   'parcito': 483,
#   'sbravacciato': 484,
#   'guardaroba': 485,
#   'manufatturarla': 486,
#   'tisero': 487,
#   'piumacciato': 488,
#   'fige': 489,
#   'intus': 490,
#   'poniam': 491,
#   'rincrescere': 492,
#   'festeggiarlo': 493,
#   'blamable': 494,
#   'ducesse': 495,
#   'sprazzo': 496,
#   'pascersi': 497,
#   'involontario': 498,
#   'afferrandola': 499,
#   'ragionamento': 500,
#   'frasca': 501,
#   'sbottonatolo': 502,
#   'ritradotto': 503,
#   'disarmare': 504,
#   'gioanna': 505,
#   'avvilirci': 506,
#   'suspiria': 507,
#   'facundis': 508,
#   'condoglienza': 509,
#   'tetestimonianze': 510,
#   'schizzetti': 511,
#   'personcina': 512,
#   'dubito': 513,
#   'imperiali': 514,
#   'pareami': 515,
#   'assicurandosi': 516,
#   'cappuccine': 517,
#   'concertato': 518,
#   'tresandello': 519,
#   'distornare': 520,
#   'aristofan': 521,
#   'trebbe': 522,
#   'versabilità': 523,
#   'folla': 524,
#   'humanarum': 525,
#   'melendez': 526,
#   'prestrino': 527,
#   'engel': 528,
#   'collocato': 529,
#   'umbilico': 530,
#   'potrebbonsi': 531,
#   'essaminano': 532,
#   'rappresentiamoci': 533,
#   'prototipo': 534,
#   'corr': 535,
#   'viaggiatore': 536,
#   'romorosi': 537,
#   'dispiacciono': 538,
#   'investito': 539,
#   'poe': 540,
#   'devotiss': 541,
#   'disanimasse': 542,
#   'enfatici': 543,
#   'imbecili': 544,
#   'jevre': 545,
#   'pendea': 546,
#   'rivocare': 547,
#   'telescopi': 548,
#   'apresta': 549,
#   'schernita': 550,
#   'obbligandomi': 551,
#   'riconoscerli': 552,
#   'introdottivi': 553,
#   'impeciati': 554,
#   'disciplinabili': 555,
#   'optima': 556,
#   'armico': 557,
#   'richardcocurdelion': 558,
#   'coalimentossi': 559,
#   'publicarne': 560,
#   'nuvoloni': 561,
#   'scriptor': 562,
#   'venutami': 563,
#   'grano': 564,
#   'immergano': 565,
#   'stoccada': 566,
#   'coperta': 567,
#   'enunziar': 568,
#   'olivier': 569,
#   'compongono': 570,
#   'derrate': 571,
#   'persuadette': 572,
#   'lavorante': 573,
#   'bova': 574,
#   'corrergli': 575,
#   'accozzando': 576,
#   'gesteggiatori': 577,
#   'manc': 578,
#   'sopralodato': 579,
#   'frali': 580,
#   'galans': 581,
#   'circoscritta': 582,
#   'arrogantiam': 583,
#   'adescata': 584,
#   'geonameid': 585,
#   'cinti': 586,
#   'montoni': 587,
#   'caffiero': 588,
#   'sedessi': 589,
#   'acquistarsi': 590,
#   'calunia': 591,
#   'aromatico': 592,
#   'presentarle': 593,
#   'accortissima': 594,
#   'degere': 595,
#   'utcheson': 596,
#   'orgoeuil': 597,
#   'precipitando': 598,
#   'oserà': 599,
#   'storicomorali': 600,
#   'inevitabile': 601,
#   'scabrosi': 602,
#   'combattea': 603,
#   'lingue': 604,
#   'rimasevi': 605,
#   'vociare': 606,
#   'comprovò': 607,
#   'sclavone': 608,
#   'tasia': 609,
#   'nostis': 610,
#   'prontinus': 611,
#   'amorosi': 612,
#   'faudra': 613,
#   'impiastri': 614,
#   'teologici': 615,
#   'significarle': 616,
#   'fondasi': 617,
#   'decreti': 618,
#   'ventoso': 619,
#   'vincerlo': 620,
#   'tunisini': 621,
#   'rilettere': 622,
#   'perdonargliela': 623,
#   'comici': 624,
#   'ischiamazzano': 625,
#   'feconde': 626,
#   'andommi': 627,
#   'spagnuolo': 628,
#   'violabile': 629,
#   'poggiuolo': 630,
#   'imitation': 631,
#   'suffurargli': 632,
#   'fulvia': 633,
#   'geneve': 634,
#   'espulse': 635,
#   'arba': 636,
#   'tapezzerie': 637,
#   'dipendenti': 638,
#   'spartirsi': 639,
#   'impiegarà': 640,
#   'guazzesi': 641,
#   'quaereretur': 642,
#   'ezian': 643,
#   'augustini': 644,
#   'entriamo': 645,
#   'incostanza': 646,
#   'callissoni': 647,
#   'accresere': 648,
#   'palandra': 649,
#   'escorter': 650,
#   'remeritasse': 651,
#   'sforzandosi': 652,
#   'talmudisti': 653,
#   'amulete': 654,
#   'avuti': 655,
#   'matrone': 656,
#   'recandole': 657,
#   'difficle': 658,
#   'instituta': 659,
#   'bulichi': 660,
#   'allongare': 661,
#   'eliconia': 662,
#   'frangit': 663,
#   'fatone': 664,
#   'pavone': 665,
#   'cacciano': 666,
#   'complicate': 667,
#   'eye': 668,
#   'contemplationis': 669,
#   'onorificenza': 670,
#   'ciuffoleria': 671,
#   'formaggelle': 672,
#   'battelletti': 673,
#   'temersi': 674,
#   'frusone': 675,
#   'prononciarle': 676,
#   'caselini': 677,
#   'trionfava': 678,
#   'carmen': 679,
#   'leggermi': 680,
#   'chiarastella': 681,
#   'battesimi': 682,
#   'agramente': 683,
#   'ballato': 684,
#   'quolibetatore': 685,
#   'guadagnare': 686,
#   'emulazioue': 687,
#   'reggonsi': 688,
#   'patav': 689,
#   'ammaestrasse': 690,
#   'lavoratrice': 691,
#   'nocevoli': 692,
#   'segnalare': 693,
#   'lozo': 694,
#   'trovisi': 695,
#   'marinoni': 696,
#   'sovente': 697,
#   'ubbidientissima': 698,
#   'telas': 699,
#   'orribilissime': 700,
#   'imprestiti': 701,
#   'annunziai': 702,
#   'commercj': 703,
#   'tuæ': 704,
#   'anchesso': 705,
#   'palemone': 706,
#   'polachetta': 707,
#   'tenerlasi': 708,
#   'porgi': 709,
#   'gorgoragorano': 710,
#   'consideratamente': 711,
#   'turbolenze': 712,
#   'an': 713,
#   'pareccchi': 714,
#   'coriolano': 715,
#   'toglierle': 716,
#   'soavissimi': 717,
#   'illusore': 718,
#   'innegabilissima': 719,
#   'spiritare': 720,
#   'carrozzini': 721,
#   'trapezzia': 722,
#   'essemminati': 723,
#   'terna': 724,
#   'bottiglia': 725,
#   'gittate': 726,
#   'bonamico': 727,
#   'spinaio': 728,
#   'increspato': 729,
#   'bonta': 730,
#   'sapori': 731,
#   'provandovelo': 732,
#   'rifformatore': 733,
#   'democrazie': 734,
#   'essaj': 735,
#   'studiava': 736,
#   'meschiai': 737,
#   'raccendere': 738,
#   'perniciosissimo': 739,
#   'dilaniarti': 740,
#   'picherni': 741,
#   'purgatevi': 742,
#   'guadagnarlo': 743,
#   'funesta': 744,
#   'restituere': 745,
#   'temuta': 746,
#   'dotali': 747,
#   'pesanti': 748,
#   'trovaremmo': 749,
#   'fraccassatesi': 750,
#   'attribuitela': 751,
#   'ragguagliarmi': 752,
#   'giurisdizioni': 753,
#   'dunnest': 754,
#   'attestare': 755,
#   'riempierne': 756,
#   'inventarne': 757,
#   'liquor': 758,
#   'rivogliesi': 759,
#   'bolino': 760,
#   'gittarsi': 761,
#   'spettatrice': 762,
#   'attraversassero': 763,
#   'suzzi': 764,
#   'mediche': 765,
#   'chiuderti': 766,
#   'colorate': 767,
#   'assalisce': 768,
#   'botteghe': 769,
#   'imitator': 770,
#   'ctesippo': 771,
#   'sperimentare': 772,
#   'miratur': 773,
#   'seguitasi': 774,
#   'kul': 775,
#   'scompone': 776,
#   'sodarini': 777,
#   'chiudeteli': 778,
#   'pastorale': 779,
#   'pudet': 780,
#   'avversare': 781,
#   'ermolao': 782,
#   'discendum': 783,
#   'spácciati': 784,
#   'colliroe': 785,
#   'ardavani': 786,
#   'notingo': 787,
#   'dʼuna': 788,
#   'polinnia': 789,
#   'ingrassa': 790,
#   'pacipari': 791,
#   'godendo': 792,
#   'samaritane': 793,
#   'agenoria': 794,
#   'frondose': 795,
#   'rectè': 796,
#   'patroncino': 797,
#   'raccomandarsi': 798,
#   'biasuti': 799,
#   'stranissime': 800,
#   'bisavo': 801,
#   'basta': 802,
#   'semigleciani': 803,
#   'sog': 804,
#   'ubbidisse': 805,
#   'montmorin': 806,
#   'attrappalo': 807,
#   'preta': 808,
#   'dolet': 809,
#   'goatin': 810,
#   'serenità': 811,
#   'gourmande': 812,
#   'incomodarvi': 813,
#   'gloriosi': 814,
#   'fantastico': 815,
#   'animerà': 816,
#   'scarabelli': 817,
#   'praefecti': 818,
#   'retorto': 819,
#   'opposte': 820,
#   'architecturæ': 821,
#   'alienæ': 822,
#   'scaltrezza': 823,
#   'perdonarmi': 824,
#   'servirlo': 825,
#   'servizii': 826,
#   'cataplasmi': 827,
#   'pascano': 828,
#   'incolti': 829,
#   'cruda': 830,
#   'immaginar': 831,
#   'orobanche': 832,
#   'sfolgorantissimo': 833,
#   'riguadagnare': 834,
#   'hacemos': 835,
#   'tradotto': 836,
#   'larginan': 837,
#   'stimargli': 838,
#   'carnepedo': 839,
#   'biffa': 840,
#   'divulgatasi': 841,
#   'malis': 842,
#   'stutgard': 843,
#   'corsogli': 844,
#   'animaux': 845,
#   'nodrisco': 846,
#   'dabile': 847,
#   'erse': 848,
#   'castagne': 849,
#   'spoetata': 850,
#   'incominciate': 851,
#   'addotti': 852,
#   'institu': 853,
#   'disturbatori': 854,
#   'esitato': 855,
#   'vissuto': 856,
#   'vigilan': 857,
#   'concorrer': 858,
#   'perdette': 859,
#   'punirlo': 860,
#   'estinguano': 861,
#   'salieri': 862,
#   'ricerverla': 863,
#   'cimarosa': 864,
#   'verrons': 865,
#   'innamorata': 866,
#   'pietate': 867,
#   'costaggiù': 868,
#   'cartella': 869,
#   'corina': 870,
#   'devolute': 871,
#   'colbert': 872,
#   'dàgli': 873,
#   'infuori': 874,
#   'presciegliere': 875,
#   'riputarsi': 876,
#   'piacquevi': 877,
#   'dimandandone': 878,
#   'marmotte': 879,
#   'seppellirci': 880,
#   'berillo': 881,
#   'duoli': 882,
#   'cinquemila': 883,
#   'vigne': 884,
#   'intrinsecarmi': 885,
#   'svelto': 886,
#   'interrogarmi': 887,
#   'mantelli': 888,
#   'oratoro': 889,
#   'desidereremmo': 890,
#   'stommachevole': 891,
#   'bollenti': 892,
#   'similissime': 893,
#   'peretti': 894,
#   'granati': 895,
#   'avant': 896,
#   'chara': 897,
#   'pojana': 898,
#   'carovane': 899,
#   'almisan': 900,
#   'vinati': 901,
#   'melitich': 902,
#   'moverà': 903,
#   'susceperunt': 904,
#   'finch': 905,
#   'ingenuo': 906,
#   'baruffanti': 907,
#   'quala': 908,
#   'campeggiare': 909,
#   'festeggiamento': 910,
#   'canisano': 911,
#   'abbracciati': 912,
#   'bisognano': 913,
#   'innutrisca': 914,
#   'ripetersi': 915,
#   'comunissima': 916,
#   'kr': 917,
#   'immaginandosi': 918,
#   'intervien': 919,
#   'testamentario': 920,
#   'osiri': 921,
#   'auditif': 922,
#   'n.q': 923,
#   'parentesque': 924,
#   'vilipendere': 925,
#   'ventitrè': 926,
#   'contavasi': 927,
#   'rassare': 928,
#   'spettatori': 929,
#   'paupertatis': 930,
#   'quattromila': 931,
#   'ruffiano': 932,
#   'formosa': 933,
#   'addottorata': 934,
#   'gilli': 935,
#   'penetrante': 936,
#   'impertinentissime': 937,
#   'dese': 938,
#   'focosa': 939,
#   'astutaccio': 940,
#   'polimone': 941,
#   'calabrazzo': 942,
#   'caffe': 943,
#   'vescicatoj': 944,
#   'soudain': 945,
#   'stregarie': 946,
#   'auxisti': 947,
#   'amaretto': 948,
#   'hercle': 949,
#   'covacciolo': 950,
#   'puerizia': 951,
#   'capottino': 952,
#   'agitatamente': 953,
#   'accrescevasi': 954,
#   'amido': 955,
#   'estraneo': 956,
#   'diserta': 957,
#   'mensonges': 958,
#   'soprammentovato': 959,
#   'opprimevano': 960,
#   'cenò': 961,
#   'richiegga': 962,
#   'castro': 963,
#   'reinart': 964,
#   'inospiti': 965,
#   'foderato': 966,
#   'perseguitano': 967,
#   'arrabbiansi': 968,
#   'trenta': 969,
#   'crispino': 970,
#   'commendati': 971,
#   'avez': 972,
#   'casali': 973,
#   'mitología': 974,
#   'peatteri': 975,
#   'gittale': 976,
#   'joui': 977,
#   'rampicone': 978,
#   'standomi': 979,
#   'covielli': 980,
#   'soavita': 981,
#   'assediare': 982,
#   'rusca': 983,
#   'decisi': 984,
#   'cancrenate': 985,
#   'favorem': 986,
#   'dʼesso': 987,
#   'rhynfault': 988,
#   'sentendolo': 989,
#   'riduzion': 990,
#   'caldissima': 991,
#   'trovatomi': 992,
#   'scolorito': 993,
#   'sere': 994,
#   'barbuto': 995,
#   'turatamente': 996,
#   'promulgazione': 997,
#   'figuranti': 998,
#   'suggerì': 999,
#   'rossiglione': 1000,
#   ...})

# %% [markdown]
# #### 1.4.2 Small corpus matrix
#
# <i>Otherwise, use the document-term matrix desigend for small corpora.<i>

# %%
#document_term_matrix = preprocessing.create_document_term_matrix(tokenized_corpus, meta['author']+'_'+meta['periodical']+'_'+meta['title']+'_'+meta['id'])
#document_term_matrix[:5]

# %% [markdown]
# ### 1.5. Feature removal
#
# <i>*Stopwords* (also known as *most frequent tokens*) and *hapax legomena* are harmful for LDA and have to be removed from the corpus or the document-term matrix respectively. In this example, the 50 most frequent tokens will be categorized as stopwords.
#
# **Hint**: Be careful with removing most frequent tokens, you might remove tokens quite important for LDA. Anyway, to gain better results, it is highly recommended to use an external stopwords list.
#
# In this notebook, we combine the 50 most frequent tokens, hapax legomena and an external stopwordslist.</i>

# %% [markdown]
# #### List the 100 most frequent words
#
# <i>If you have chosen the large corpus model, you will have to add `type_ids` to the function `preprocessing.list_mfw()`.</i><br>
# So, if you created a matrix for a large corpus, write this as a third argument: `type_ids=type_ids`.

# %%
stopwords = preprocessing.list_mfw(document_term_matrix, most_frequent_tokens=100, type_ids=type_ids) #, type_ids=type_ids

# %% [markdown]
# <i>These are the five most frequent words:</i>

# %%
stopwords[:10]
# Out:
# ['di', 'il', 'che', 'la', 'essere', 'non', 'in', 'un', 'per', 'della']

# %% [markdown]
# #### List hapax legomena

# %% [markdown]
# Again, if you created a large matrix, you have to add/change a few arguments.<br>
# For `preprocessing.find_hapax_legomena` just add `type_ids`. To find out the total number of types use `len(type_ids)` instead of `document_term_matrix.shape[1]`.<br>
#
# __For a large corpus:__

# %%
hapax_legomena = preprocessing.find_hapax_legomena(document_term_matrix, type_ids) 
print("Total number of types in corpus:", len(type_ids))
print("Total number of hapax legomena:", len(hapax_legomena))
# Out:
# Total number of types in corpus: 108661
# Total number of hapax legomena: 55145

# %% [markdown]
# __For a small corpus:__

# %%
#hapax_legomena = preprocessing.find_hapax_legomena(document_term_matrix) 
#print("Total number of types in corpus:", document_term_matrix.shape[1]) 
#print("Total number of hapax legomena:", len(hapax_legomena))

# %% [markdown]
# #### Optional: Use external stopwordlist

# %%
path_to_stopwordlist = Path(data, 'stopwords', language+'.txt')
external_stopwords = [line.strip() for line in path_to_stopwordlist.open('r', encoding='utf-8')]
external_stopwords[:20]
# Out:
# ['a',
#  'abbastanza',
#  'abbia',
#  'abbiamo',
#  'abbiano',
#  'abbiate',
#  'accidenti',
#  'ad',
#  'adesso',
#  'affinche',
#  'agl',
#  'agli',
#  'ahime',
#  'ahimã¨',
#  'ahimè',
#  'ai',
#  'al',
#  'alcuna',
#  'alcuni',
#  'alcuno']

# %% [markdown]
# #### Combine lists and remove content from `tokenized_corpus`
# __Add `type_ids=type_ids` if you have a large corpus.__

# %%
features = stopwords + hapax_legomena + external_stopwords
clean_tokenized_corpus = list(preprocessing.remove_features(features, tokenized_corpus=tokenized_corpus, type_ids=type_ids)) #, type_ids=type_ids

# %% [markdown]
# Save the features list to remove them as stop words for the word clouds in the visualization workflow.

# %%
total_stopwords = ' '.join(features)
with open(data+'/stopwords/'+ language+'_features.txt', 'w+', encoding='utf-8') as f:
    f.write(total_stopwords)

# %% [markdown]
# ## 2. Model creation

# %% [markdown]
# #### Path to MALLET folder
#
# <i>Now we must tell the library where to find the local instance of MALLET. If you managed to install MALLET, it is sufficient set `path_to_mallet = 'mallet'`, if you store MALLET in a local folder, you have to specify the path to the binary explictly (e.g. `path_to_mallet = 'C:/mallet-2.0.8/bin/mallet'`).
#
# **Whitespaces are not allowed in the path!**</i>
#
# MALLET has to be installed directly under C:. __If you are using Linux__, then you don't need to use the '.bat' extension, __otherwhise you have to specify that__.

# %%
"""
path_to_mallet = 'C:/mallet-2.0.8/bin/mallet
"""
path_to_mallet = 'C:/mallet-2.0.8/bin/mallet.bat'

# %% [markdown]
# ### 2.1. Create `Mallet` object
#
# <i>Finally, we can instance the `Mallet` object.<i>

# %%
Mallet = utils.Mallet(path_to_mallet)

# %%
help(Mallet)
# Out:
# Help on Mallet in module dariah_topics.utils object:
#
# class Mallet(builtins.object)
#  |  Mallet(executable='mallet', corpus_output=None, logfile=False)
#  |
#  |  Python wrapper for MALLET.
#  |
#  |  With this class you can call the command-line tool `MALLET <http://mallet.cs.umass.edu/topics.php>`_     from within Python.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, executable='mallet', corpus_output=None, logfile=False)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  call_mallet(self, command, **kwargs)
#  |      Calls the command-line tool MALLET.
#  |
#  |      With this function you can call `MALLET <http://mallet.cs.umass.edu/topics.php>`_         using a specific ``command`` (e.g. ``train-topics``) and its parameters.
#  |      **Whitespaces (especially for Windows users) are not allowed in paths.**
#  |
#  |      Args:
#  |          command (str): A MALLET command, this could be ``import-dir`` (load
#  |              the contents of a directory into MALLET instances), ``import-file``
#  |              (load a single file into MALLET instances), ``import-svmlight``
#  |              (load SVMLight format data files into MALLET instances), ``info``
#  |              (get information about MALLET instances), ``train-classifier``
#  |              (train a classifier from MALLET data files), ``classify-dir``
#  |              (classify data from a single file with a saved classifier), ``classify-file``
#  |              (classify the contents of a directory with a saved classifier),
#  |              ``classify-svmlight`` (classify data from a single file in SVMLight
#  |              format), ``train-topics`` (train a topic model from MALLET data
#  |              files), ``infer-topics`` (use a trained topic model to infer topics
#  |              for new documents), ``evaluate-topics`` (estimate the probability
#  |              of new documents under a trained model), ``prune`` (remove features
#  |              based on frequency or information gain), ``split`` (divide data
#  |              into testing, training, and validation portions), ``bulk-load``
#  |              (for big input files, efficiently prune vocabulary and import docs).
#  |
#  |      Returns:
#  |          :class:`Popen` object of the MALLET subprocess.
#  |
#  |      Example:
#  |          >>> import tempfile
#  |          >>> with tempfile.NamedTemporaryFile(suffix='.txt') as tmpfile:
#  |          ...     tmpfile.write(b"This is a plain text example.") and True
#  |          ...     tmpfile.flush()
#  |          ...     Mallet = Mallet(corpus_output='.')
#  |          ...     process = Mallet.call_mallet('import-file', input=tmpfile.name)
#  |          ...     os.path.exists('text.vectors')
#  |          True
#  |          True
#  |
#  |  import_tokenized_corpus(self, tokenized_corpus, document_labels, **kwargs)
#  |      Creates MALLET corpus model.
#  |
#  |      With this function you can import a ``tokenized_corpus`` to create the         MALLET corpus model. The MALLET command for this step is ``import-dir``         with ``--keep-sequence`` (which is already defined in the function, so         you don't have to), but you have the ability to specify all available         parameters. The output will be saved in ``output_corpus``.
#  |
#  |      Args:
#  |          tokenized_corpus (list): Tokenized corpus containing one or more
#  |              iterables containing tokens.
#  |          document_labels (list): Name of each `tokenized_document` in `tokenized_corpus`.
#  |          encoding (str): Character encoding for input file. Defaults to UTF-8.
#  |          token_regex (str): Divides documents into tokens using a regular
#  |              expression (supports Unicode regex). Defaults to \p{L}[\p{L}\p{P}]+\p{L}.
#  |          preserve_case (bool): If False, converts all word features to lowercase.
#  |              Defaults to False.
#  |          remove_stopwords (bool): Ignores a standard list of very common English
#  |              tokens. Defaults to True.
#  |          stoplist (str): Absolute path to plain text stopword list. Defaults to None.
#  |          extra_stopwords (str): Read whitespace-separated words from this file,
#  |              and add them to either the default English stoplist or the list
#  |              specified by ``stoplist``. Defaults to None.
#  |          stop_pattern_file (str): Read regular expressions from a file, one per
#  |              line. Tokens matching these regexps will be removed. Defaults to None.
#  |          skip_header (bool): If True, in each document, remove text occurring
#  |              before a blank line. This is useful for removing email or UseNet
#  |              headers. Defaults to False.
#  |          skip_html (bool): If True, remove text occurring inside <...>, as in
#  |              HTML or SGML. Defaults to False.
#  |          replacement_files (str): Files containing string replacements, one per
#  |              line: 'A B [tab] C' replaces A B with C, 'A B' replaces A B with A_B.
#  |              Defaults to None.
#  |          deletion_files (str): Files containing strings to delete after
#  |              `replacements_files` but before tokenization (i.e. multiword stop
#  |              terms). Defaults to False.
#  |          keep_sequence_bigrams (bool): If True, final data will be a
#  |              FeatureSequenceWithBigrams rather than a FeatureVector. Defaults to False.
#  |          binary_features (bool): If True, features will be binary. Defaults to False.
#  |          save_text_in_source (bool): If True, save original text of document in source.
#  |              Defaults to False.
#  |          print_output (bool): If True, print a representation of the processed data
#  |              to standard output. This option is intended for debugging. Defaults to
#  |              False.
#  |
#  |      Returns:
#  |          The absolute path to the created MALLET corpus file.
#  |
#  |      Example:
#  |          >>> tokenized_corpus = [['this', 'is', 'a', 'tokenized', 'document']]
#  |          >>> document_labels = ['document_label']
#  |          >>> mallet = Mallet(corpus_output='.')
#  |          >>> mallet_corpus = mallet.import_tokenized_corpus(tokenized_corpus, document_labels)
#  |          >>> os.path.exists('corpus.mallet')
#  |          True
#  |
#  |  train_topics(self, mallet_binary, cleanup=False, **kwargs)
#  |      Trains LDA model.
#  |
#  |      With this function you can train a topic model. The MALLET command for         this step is ``train-topics`` (which is already defined in the function,         so you don't have to), but you have the ability to specify all available         parameters.
#  |
#  |      Args:
#  |          mallet_binary (str): Path to MALLET corpus model.
#  |          cleanup (bool): If True, the directory ``corpus_output`` will be removed
#  |              after modeling.
#  |          input_model (str): The filename from which to read the binary topic
#  |              model.
#  |          input_state (str): The filename from which to read the gzipped Gibbs
#  |              sampling state created by ``output_state``. The original input
#  |              file must be included, using ``input``.
#  |          output_model (str): The filename in which to write the binary topic
#  |              model at the end of the iterations.
#  |          output_state (str): The filename in which to write the Gibbs sampling
#  |              state after at the end of the iterations.
#  |          output_model_interval (int): The number of iterations between writing
#  |              the model (and its Gibbs sampling state) to a binary file. You must
#  |              also set the ``output_model`` to use this option, whose argument
#  |              will be the prefix of the filenames. Default is 0.
#  |          output_state_interval (int): The number of iterations between
#  |              writing the sampling state to a text file. You must also set
#  |              the ``output_state`` to use this option, whose argument will be
#  |              the prefix of the filenames. Default is 0.
#  |          inferencer_filename (str): A topic inferencer applies a previously
#  |              trained topic model to new documents.
#  |          evaluator_filename (str): A held-out likelihood evaluator for new documents.
#  |          output_topic_keys (str): The filename in which to write the top
#  |              words for each topic and any Dirichlet parameters.
#  |          num_top_words (int): The number of most probable words to print for
#  |              each topic after model estimation. Default is 20.
#  |          show_topics_interval (int): The number of iterations between printing
#  |              a brief summary of the topics so far. Default is 50.
#  |          topic_word_weights_file (str): The filename in which to write
#  |              unnormalized weights for every topic and word type.
#  |          word_topic_counts_file (str): The filename in which to write a sparse
#  |              representation of topic-word assignments.
#  |          diagnostics_file (str): The filename in which to write measures of
#  |              topic quality, in XML format.
#  |            Default is null
#  |          xml_topic_report (str): The filename in which to write the top words
#  |              for each topic and any Dirichlet parameters in XML format.
#  |          xml_topic_phrase_report (str): The filename in which to write the top
#  |              words and phrases for each topic and any Dirichlet parameters in
#  |              XML format.
#  |          num_top_docs (int): When writing topic documents with ``output_topic_docs``,
#  |              report this number of top documents. Default is 100
#  |          output_doc_topics (str): The filename in which to write the topic
#  |              proportions per document, at the end of the iterations.
#  |          doc_topics_threshold (float): Do not print topics with proportions less
#  |              than this threshold value within ``output_doc_topics``. Defaults to 0.0.
#  |          num_topics (int): Number of topics. Defaults to 10.
#  |          num_top_words (int): Number of keywords for each topic. Defaults to 10.
#  |          num_interations (int): Number of iterations. Defaults to 1000.
#  |          num_threads (int): Number of threads for parallel training.  Defaults to 1.
#  |          num_icm_iterations (int): Number of iterations of iterated conditional
#  |              modes (topic maximization).  Defaults to 0.
#  |          no_inference (bool): Load a saved model and create a report. Equivalent
#  |              to ``num_iterations = 0``. Defaults to False.
#  |          random_seed (int): Random seed for the Gibbs sampler. Defaults to 0.
#  |          optimize_interval (int): Number of iterations between reestimating
#  |              dirichlet hyperparameters. Defaults to 0.
#  |          optimize_burn_in (int): Number of iterations to run before first
#  |              estimating dirichlet hyperparameters. Defaults to 200.
#  |          use_symmetric_alpha (bool): Only optimize the concentration parameter of
#  |              the prior over document-topic distributions. This may reduce the
#  |              number of very small, poorly estimated topics, but may disperse common
#  |              words over several topics. Defaults to False.
#  |          alpha (float): Sum over topics of smoothing over doc-topic distributions.
#  |              ``alpha_k = [this value] / [num topics]``. Defaults to 5.0.
#  |          beta (float): Smoothing parameter for each topic-word. Defaults to 0.01.
#  |
#  |      Returns:
#  |          None.
#  |
#  |      Example:
#  |          >>> tokenized_corpus = [['this', 'is', 'a', 'tokenized', 'document']]
#  |          >>> document_labels = ['document_label']
#  |          >>> mallet = Mallet(corpus_output='.')
#  |          >>> mallet_corpus = mallet.import_tokenized_corpus(tokenized_corpus, document_labels)
#  |          >>> mallet_topics = mallet.train_topics(mallet_corpus,
#  |          ...                                     output_model='model.mallet',
#  |          ...                                     num_iterations=10)
#  |          >>> os.path.exists('model.mallet')
#  |          True
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# <i>The object `Mallet` has a method `import_tokenized_corpus()` to create a specific corpus file for MALLET.</i>
#
# Adjust the argument meta with the metadata of your choice. Be carefull not to overwrite with non distinctive properties.

# %%
mallet_corpus = Mallet.import_tokenized_corpus(clean_tokenized_corpus, meta['year']+'_'+meta['periodical']+'_'+meta['author']+'_'+meta['volume']+'_'+meta['issue']+'_'+meta['id']+'_'+meta['chunk'])

# %%
help(Mallet.import_tokenized_corpus)
# Out:
# Help on method import_tokenized_corpus in module dariah_topics.utils:
#
# import_tokenized_corpus(tokenized_corpus, document_labels, **kwargs) method of dariah_topics.utils.Mallet instance
#     Creates MALLET corpus model.
#
#     With this function you can import a ``tokenized_corpus`` to create the         MALLET corpus model. The MALLET command for this step is ``import-dir``         with ``--keep-sequence`` (which is already defined in the function, so         you don't have to), but you have the ability to specify all available         parameters. The output will be saved in ``output_corpus``.
#
#     Args:
#         tokenized_corpus (list): Tokenized corpus containing one or more
#             iterables containing tokens.
#         document_labels (list): Name of each `tokenized_document` in `tokenized_corpus`.
#         encoding (str): Character encoding for input file. Defaults to UTF-8.
#         token_regex (str): Divides documents into tokens using a regular
#             expression (supports Unicode regex). Defaults to \p{L}[\p{L}\p{P}]+\p{L}.
#         preserve_case (bool): If False, converts all word features to lowercase.
#             Defaults to False.
#         remove_stopwords (bool): Ignores a standard list of very common English
#             tokens. Defaults to True.
#         stoplist (str): Absolute path to plain text stopword list. Defaults to None.
#         extra_stopwords (str): Read whitespace-separated words from this file,
#             and add them to either the default English stoplist or the list
#             specified by ``stoplist``. Defaults to None.
#         stop_pattern_file (str): Read regular expressions from a file, one per
#             line. Tokens matching these regexps will be removed. Defaults to None.
#         skip_header (bool): If True, in each document, remove text occurring
#             before a blank line. This is useful for removing email or UseNet
#             headers. Defaults to False.
#         skip_html (bool): If True, remove text occurring inside <...>, as in
#             HTML or SGML. Defaults to False.
#         replacement_files (str): Files containing string replacements, one per
#             line: 'A B [tab] C' replaces A B with C, 'A B' replaces A B with A_B.
#             Defaults to None.
#         deletion_files (str): Files containing strings to delete after
#             `replacements_files` but before tokenization (i.e. multiword stop
#             terms). Defaults to False.
#         keep_sequence_bigrams (bool): If True, final data will be a
#             FeatureSequenceWithBigrams rather than a FeatureVector. Defaults to False.
#         binary_features (bool): If True, features will be binary. Defaults to False.
#         save_text_in_source (bool): If True, save original text of document in source.
#             Defaults to False.
#         print_output (bool): If True, print a representation of the processed data
#             to standard output. This option is intended for debugging. Defaults to
#             False.
#
#     Returns:
#         The absolute path to the created MALLET corpus file.
#
#     Example:
#         >>> tokenized_corpus = [['this', 'is', 'a', 'tokenized', 'document']]
#         >>> document_labels = ['document_label']
#         >>> mallet = Mallet(corpus_output='.')
#         >>> mallet_corpus = mallet.import_tokenized_corpus(tokenized_corpus, document_labels)
#         >>> os.path.exists('corpus.mallet')
#         True

# %% [markdown]
# <i>Furthermore, `Mallet` has the method `train_topics()` to create and train the LDA model. To create a LDA model, there have to be specified a couple of parameters.
#
# But first, if you are curious about any library, module, class or function, try `help()`. This can be very useful, because (at least in a well documented library) explanations of use and parameters will be printed. We're interested in the function `Mallet.train_topics()` in the module `dariah_topics.mallet`, so let's try:
#
# ```
# help(mallet.Mallet)
# ```
#
# This will print something like this (in fact even more):
#
# ```
# Help on method train_topics in module dariah_topics.mallet:
#
# train_topics(mallet_binary, **kwargs) method of dariah_topics.mallet.Mallet instance
#     Args:
#         input_model (str): Absolute path to the binary topic model created by `output_model`.
#         output_model (str): Write a serialized MALLET topic trainer object.
#             This type of output is appropriate for pausing and restarting training,
#             but does not produce data that can easily be analyzed.
#         output_topic_keys (str): Write the top words for each topic and any
#             Dirichlet parameters to file.
#         topic_word_weights_file (str): Write unnormalized weights for every
#             topic and word type.
#         word_topic_counts_file (str): Write a sparse representation of topic-word
#             assignments. By default this is null, indicating that no file will
#             be written.
#         output_doc_topics (str): Write the topic proportions per document, at
#             the end of the iterations.
#         num_topics (int): Number of topics. Defaults to 10.
#         num_top_words (int): Number of keywords for each topic. Defaults to 10.
#         num_interations (int): Number of iterations. Defaults to 1000.
#         num_threads (int): Number of threads for parallel training.  Defaults to 1.
#         num_icm_iterations (int): Number of iterations of iterated conditional
#             modes (topic maximization).  Defaults to 0.
#         no_inference (bool): Load a saved model and create a report. Equivalent
#             to `num_iterations = 0`. Defaults to False.
#         random_seed (int): Random seed for the Gibbs sampler. Defaults to 0.
#         optimize_interval (int): Number of iterations between reestimating
#             dirichlet hyperparameters. Defaults to 0.
#         optimize_burn_in (int): Number of iterations to run before first
#             estimating dirichlet hyperparameters. Defaults to 200.
#         use_symmetric_alpha (bool): Only optimize the concentration parameter of
#             the prior over document-topic distributions. This may reduce the
#             number of very small, poorly estimated topics, but may disperse common
#             words over several topics. Defaults to False.
#         alpha (float): Sum over topics of smoothing over doc-topic distributions.
#             alpha_k = [this value] / [num topics]. Defaults to 5.0.
#         beta (float): Smoothing parameter for each topic-word. Defaults to 0.01.
# ```
#
# So, now you know how to define the number of topics and the number of sampling iterations as well. A higher number of iterations will probably yield a better model, but also increases processing time. `alpha` and `beta` are so-called *hyperparameters*. They influence the model's performance, so feel free to play around with them. In the present example, we will leave the default values. Furthermore, there exist various methods for hyperparameter optimization, e.g. gridsearch or Gaussian optimization.
#
# **Warning: This step can take quite a while!** Meaning something between some seconds and some hours depending on corpus size and the number of iterations. Our example corpus should be done within a minute or two at `num_iterations=1000`.</i>

# %% [markdown]
# <i>First, create an output folder</i>. Set the variables `num_topics`, `num_iterations` and `optimize_interval` you will use for modelling to also generate the file and directory names.

# %%
num_topics=22
num_iterations=2000
optimize_interval=20

output = data + '/output/Dariah_IntroducingMallet/'+language+'/'+dt_string.split('-')[0]+'_n'+str(num_topics)+'_i'+str(num_iterations)+'_opt'+str(optimize_interval)+'_paragr'
if not os.path.exists(output):
    os.makedirs(output)
output
# Out:
# 'Y:/data/projekte/dispecs/TopicModeling/output/Dariah_IntroducingMallet/it/20210520_n22_i2000_opt20_paragr'

# %% [markdown]
# Now we use the variable `dt_string` to include the information in our file and directory names.
#
# If you use the version we suggest, you might want to leave out the `%%time` command, since it causes some problems in jupyter notebook.

# %%
"""
# %%time

Mallet.train_topics(mallet_corpus,
                    output_topic_keys=str(Path(output, 'topic_keys.txt')),
                    output_doc_topics=str(Path(output, 'doc_topics.txt')),
                    num_topics=10,
                    num_iterations=1000)
"""
"""
topic_word_weights_file (str): Write unnormalized weights for every
            topic and word type.
        word_topic_counts_file (str): Write a sparse representation of topic-word
            assignments. By default this is null, indicating that no file will
            be written.
        
"""
#%%time  
#num_topics=25
#num_iterations=2000
#optimize_interval=20
topic_keys_output = dt_string + '_' + 'topic_keys'+ '_n'+ str(num_topics) + '_i' + str(num_iterations) + '_opt'+ str(optimize_interval) + '.txt'
doc_topics_output = dt_string + '_' + 'doc_topics'+ '_n'+ str(num_topics) + '_i' + str(num_iterations) + '_opt'+ str(optimize_interval) + '.txt'
topic_word_weights_file = dt_string + '_' + 'topic_word_weights'+ '_n'+ str(num_topics) + '_i' + str(num_iterations) + '_opt'+ str(optimize_interval) + '.txt'
#word_topic_counts_file = dt_string + '_' + 'word_topic_counts'+ '_n'+ str(num_topics) + '_i' + str(num_iterations) + '_opt'+ str(optimize_interval) + '.txt'

Mallet.train_topics(mallet_corpus,
                    output_topic_keys=str(Path(output, topic_keys_output)),
                    output_doc_topics=str(Path(output, doc_topics_output)),
                    num_topics=num_topics,
                    num_iterations=num_iterations,
                    optimize_interval=optimize_interval,
                    topic_word_weights_file=str(Path(output, topic_word_weights_file)),
                    )

# %%
str(Path(output, topic_word_weights_file))
# Out:
# 'Y:\\data\\projekte\\dispecs\\TopicModeling\\output\\Dariah_IntroducingMallet\\it\\20210520_n22_i2000_opt20_paragr\\20210520-1117_topic_word_weights_n22_i2000_opt20.txt'

# %% [markdown]
# <i>If you are curious about MALLET's logging, have a look at the file `mallet.log`, which should have been created in the same directory as your notebook is.</i>

# %% [markdown]
# __Save__ the final (clean) document term list for future analysis and visualization.

# %%
matrix_path =  str(output).replace('\\', '/') + '/' + dt_string + '_dtl.pkl'

final_frequencies = []
for li in clean_tokenized_corpus:  
    counts = Counter(li)
    final_frequencies.append(counts)  

res = final_frequencies[0]
for c in final_frequencies[1:]: 
    res += c
res

f = open(matrix_path,"wb")
pickle.dump(dict(res),f)
f.close()

print('Document term list saved as pickle in ' + matrix_path)
# Out:
# Document term list saved as pickle in Y:/data/projekte/dispecs/TopicModeling/output/Dariah_IntroducingMallet/it/20210520_n22_i2000_opt20_paragr/20210520-1117_dtl.pkl

# %% [markdown]
# __Save__ a reduced version of the topic_word_weights_file.

# %%
a_file = open(str(output+"/" + topic_word_weights_file), "r", encoding="utf8")

lines = a_file.readlines()
a_file.close()

new_file = open(str(output+"/"
                    + dt_string + '_' + 'topic_word_weights'+ '_n'+ str(num_topics) 
                    + '_i' + str(num_iterations) + '_opt'+ str(optimize_interval) 
                    + '_reduced.txt'), "w",encoding="utf8")
for line in lines:
    if '\t0.0' not in line:
        new_file.write(line)

new_file.close()

# %% [markdown]
# ### 2.4. Create document-topic matrix
#
# <i>The generated model object can now be translated into a human-readable document-topic matrix (that is a actually a pandas data frame) that constitutes our principle exchange format for topic modeling results. For generating the matrix from a Gensim model, we can use the following function:</i>

# %%
topics = postprocessing.show_topics(topic_keys_file=str(Path(output, topic_keys_output)))
topics
# Out:
#               Key 0     Key 1        Key 2    Key 3            Key 4  \
# Topic 0      morale     stile       poesia  poetare            poema
# Topic 1       donna     donne      parlare  persona             aria
# Topic 2       virtù    natura        cuore   tenere           menare
# Topic 3         ant    pietro        marco  antonio            franc
# Topic 4       acqua    medico        corpo     aria         medicina
# Topic 5      andare      casa         mano    notte          mettere
# Topic 6     credere     virtù      ragione   solere          rendere
# Topic 7         duc      casa         pago    calle          librajo
# Topic 8      colore    bianco         moda      oro            abito
# Topic 9         bar     oglio          bal     piel           patron
# Topic 10   scrivere     opera       autore     arte            libro
# Topic 11  ritrovare   maniera        mondo   natura         pigliare
# Topic 12     taglio     laudo        delli    causa  eccellentissimo
# Topic 13   scrivere   signore      lettera   lingua           autore
# Topic 14      padre     madre       moglie     casa            amore
# Topic 15      cielo    occhio        dolce    bello             sole
# Topic 16     teatro    musica        opera     sera            scena
# Topic 17     andare     orare        mondo  credere            cuore
# Topic 18     chiesa     città       ordine    piede          palazzo
# Topic 19      banco    ducati        soldi   ducato              oro
# Topic 20      terra   nazione  agricoltura    paese            città
# Topic 21     foglio  pubblico        città   signor          lettera
#
#                Key 5      Key 6      Key 7       Key 8        Key 9    Key 10  \
# Topic 0     commedia  carattere   scrivere       opere       autore  tragedia
# Topic 1        sesso      volto  compagnia     piacere         dama      dame
# Topic 2      piacere      animo      amore  sentimento        volto  colorire
# Topic 3       zuanne       prov  francesco        mese          gir      duro
# Topic 4     malattia    effetto        uso       volto       medici    febbre
# Topic 5        fossa    venezia      fuoco     correre      cavallo      sera
# Topic 6      spirito   lasciare    piacere       onore         puro    vivere
# Topic 7      parlare    bottega  colombani       paolo      venezia     ponte
# Topic 8       nastro     grosso    portare    cappello        donna  guarnire
# Topic 9          fag        cai        cas         bot          cap   trieste
# Topic 10      lingua    parlare     natura      storia      leggere     libri
# Topic 11     piacere      puole   naturale     collare        ponno    specie
# Topic 12  magistrato     eccell   suddetto   consiglio     giudizio   seguire
# Topic 13      italia        bue      quell      frusta          don   parlare
# Topic 14      marito      donna     figlio       cuore   matrimonio  famiglia
# Topic 15     cantare      terra    piacere         bel        orare      mano
# Topic 16       ballo   commedia    signora      musico   spettacolo    signor
# Topic 17      occhio     uscire       mano       fossa        animo  lasciare
# Topic 18     passare      santo   famiglia      teatro      vescovo     corte
# Topic 19       scudi        vol      scudo      grossi      bottega       lir
# Topic 20   commercio     prezzo       mare     terreno       natura     orare
# Topic 21  pubblicare   gazzetta       onda    scrivere  gazzettiere   signori
#
#               Key 11         Key 12     Key 13    Key 14      Key 15  \
# Topic 0      costume         secolo     teatro   ingegno        arte
# Topic 1        città  conversazione      amico      moda     signore
# Topic 2     ancorare       felicità   eziandio    andare       amico
# Topic 3          gio       giovanni        alv     balbi        cons
# Topic 4        parto       ancorare   quantità    sanità      natura
# Topic 5      versare        passare      acqua    povero      uscire
# Topic 6        volto          cuore    persona     fossa     pensare
# Topic 7       signor         chiave      caffè  contrada      genova
# Topic 8         nero          verde    collare   vestire        roso
# Topic 9        balle            lib   cassetta     manco     pieligo
# Topic 10      antico        scienza    ragione    secolo    studiare
# Topic 11       anima            dea      virtù  rimanere     versare
# Topic 12     signori         senato     interv      beni      giugno
# Topic 13    chiamare        librare  aristarco    andare   leggitori
# Topic 14     giovane       maritare      amare  figliare       fossa
# Topic 15        caro         felice   bellezza      mare       notte
# Topic 16     cantare        maestro   pubblico    teatri    recitare
# Topic 17  cominciare          volto      parea    parola      sicchè
# Topic 18     disegno        venezia    formare      sala    principe
# Topic 19         leg            cum       lire   librajo       oland
# Topic 20     nazioni         europa   produrre   restare        seta
# Topic 21     seguire           mese    venezia  numerare  presentire
#
#                  Key 16    Key 17      Key 18            Key 19
# Topic 0           opera   romanzo    francese            dramma
# Topic 1         maniera     bello      parola           passare
# Topic 2         sentire       neo      vivere             porre
# Topic 3          corner     zorzi   contarini           niccolò
# Topic 4           usare    sangue       orare           rendere
# Topic 5       ritornare   mattina       città            cadere
# Topic 6         mettere    menare    meritare          ancorare
# Topic 7             cap  affittar  appressare             porto
# Topic 8         piccolo   formare       largo     rappresentare
# Topic 9           pelle    cerare        lana               sac
# Topic 10         verità     bello    trattare           ingegno
# Topic 11        servire     cuore     persona            giusto
# Topic 12           capi     leggi        atto          avvocati
# Topic 13          bello   credere     leggere             gente
# Topic 14            età      caro      figlia         figliuoli
# Topic 15           seno     fiore        voce             amore
# Topic 16  rappresentare  applauso      autore  rappresentazione
# Topic 17       pensiero   puntare    cervello           entrare
# Topic 18          festa     marco      tempio              doge
# Topic 19           fogl   firenze        roma               sed
# Topic 20       numerare  quantità   industria       inghilterra
# Topic 21         padova   notizia        dato          soggetto

# %%
document_topics = postprocessing.show_document_topics(topics=topics,
                                                      doc_topics_file=str(Path(output, doc_topics_output)))
document_topics[:30]
# Out:
#                            1727_Il-Filosofo-alla-Moda_Cesare-Frasponi_Vol-1_Nr-000_09A-399_0000  \
# morale stile poesia                                                   0.0008
# donna donne parlare                                                   0.0447
# virtù natura cuore                                                    0.0011
# ant pietro marco                                                      0.0004
# acqua medico corpo                                                    0.0008
# andare casa mano                                                      0.0341
# credere virtù ragione                                                 0.0693
# duc casa pago                                                         0.0006
# colore bianco moda                                                    0.0111
# bar oglio bal                                                         0.0003
# scrivere opera autore                                                 0.3014
# ritrovare maniera mondo                                               0.3320
# taglio laudo delli                                                    0.0006
# scrivere signore lettera                                              0.0006
# padre madre moglie                                                    0.0015
# cielo occhio dolce                                                    0.0014
# teatro musica opera                                                   0.0008
# andare orare mondo                                                    0.0231
# chiesa città ordine                                                   0.0010
# banco ducati soldi                                                    0.0002
# terra nazione agricoltura                                             0.0013
# foglio pubblico città                                                 0.1730
#
#                            1727_Il-Filosofo-alla-Moda_Cesare-Frasponi_Vol-2_Nr-0651_09A-398_0000  \
# morale stile poesia                                                   0.0010
# donna donne parlare                                                   0.1654
# virtù natura cuore                                                    0.0015
# ant pietro marco                                                      0.0006
# acqua medico corpo                                                    0.1095
# andare casa mano                                                      0.0026
# credere virtù ragione                                                 0.0067
# duc casa pago                                                         0.0007
# colore bianco moda                                                    0.1091
# bar oglio bal                                                         0.0003
# scrivere opera autore                                                 0.0304
# ritrovare maniera mondo                                               0.2728
# taglio laudo delli                                                    0.0007
# scrivere signore lettera                                              0.0007
# padre madre moglie                                                    0.0019
# cielo occhio dolce                                                    0.0289
# teatro musica opera                                                   0.0011
# andare orare mondo                                                    0.0022
# chiesa città ordine                                                   0.0013
# banco ducati soldi                                                    0.0003
# terra nazione agricoltura                                             0.1916
# foglio pubblico città                                                 0.0707
#
#                            1727_Il-Filosofo-alla-Moda_Cesare-Frasponi_Vol-2_Nr-101_096-282_0000  \
# morale stile poesia                                                   0.0004
# donna donne parlare                                                   0.3966
# virtù natura cuore                                                    0.0005
# ant pietro marco                                                      0.0002
# acqua medico corpo                                                    0.0003
# andare casa mano                                                      0.0498
# credere virtù ragione                                                 0.0024
# duc casa pago                                                         0.0003
# colore bianco moda                                                    0.0002
# bar oglio bal                                                         0.0001
# scrivere opera autore                                                 0.0012
# ritrovare maniera mondo                                               0.4011
# taglio laudo delli                                                    0.0003
# scrivere signore lettera                                              0.0003
# padre madre moglie                                                    0.0056
# cielo occhio dolce                                                    0.0006
# teatro musica opera                                                   0.0004
# andare orare mondo                                                    0.0008
# chiesa città ordine                                                   0.0005
# banco ducati soldi                                                    0.0001
# terra nazione agricoltura                                             0.0006
# foglio pubblico città                                                 0.1378
#
#                            1727_Il-Filosofo-alla-Moda_Cesare-Frasponi_Vol-2_Nr-101_096-282_0001  \
# morale stile poesia                                                   0.0003
# donna donne parlare                                                   0.5897
# virtù natura cuore                                                    0.0083
# ant pietro marco                                                      0.0002
# acqua medico corpo                                                    0.
#
#                            1727_Il-Filosofo-alla-Moda_Cesare-Frasponi_Vol-2_Nr-103_096-284_0000  \
# morale stile poesia                                                   0.1255
# donna donne parlare                                                   0.0008
# virtù natura cuore                                                    0.0088
# ant pietro marco                                                      0.0002
# acqua medico corpo                                                    0.0003
# andare casa mano                                                      0.0300
# credere virtù ragione                                                 0.2065
# duc casa pago                                                         0.0002
# colore bianco moda                                                    0.0002
# bar oglio bal                                                         0.0001
# scrivere opera autore                                                 0.0010
# ritrovare maniera mondo                                               0.5511
# taglio laudo delli                                                    0.0002
# scrivere signore lettera                                              0.0044
# padre madre moglie                                                    0.0006
# cielo occhio dolce                                                    0.0172
# teatro musica opera                                                   0.0003
# andare orare mondo                                                    0.0007
# chiesa città ordine                                                   0.0004
# banco ducati soldi                                                    0.0001
# terra nazione agricoltura                                             0.0005
# foglio pubblico città                                                 0.0509
#
#                            1727_Il-Filosofo-alla-Moda_Cesare-Frasponi_Vol-2_Nr-103_096-284_0001  \
# morale stile poesia                                                   0.0316
# donna donne parlare                                                   0.2439
# virtù natura cuore                                                    0.0318
# ant pietro marco                                                      0.0003
# acqua medico corpo                                                    0.0004
# andare casa mano                                                      0.0883
# credere virtù ragione                                                 0.2458
# duc casa pago                                                         0.0003
# colore bianco moda                                                    0.0002
# bar oglio bal                                                         0.0001
# scrivere opera autore                                                 0.0015
# ritrovare maniera mondo                                               0.2931
# taglio laudo delli                                                    0.0003
# scrivere signore lettera                                              0.0066
# padre madre moglie                                                    0.0258
# cielo occhio dolce                                                    0.0008
# teatro musica opera                                                   0.0005
# andare orare mondo                                                    0.0072
# chiesa città ordine                                                   0.0006
# banco ducati soldi                                                    0.0001
# terra nazione agricoltura                                             0.0007
# foglio pubblico città                                                 0.0200
#
#                            ...  \
# morale stile poesia        ...
# donna donne parlare        ...
# virtù natura cuore         ...
# ant pietro marco           ...
# acqua medico corpo         ...
# andare casa mano           ...
# credere virtù ragione      ...
# duc casa pago              ...
# colore bianco moda         ...
# bar oglio bal              ...
# scrivere opera autore      ...
# ritrovare maniera mondo    ...
# taglio laudo delli         ...
# scrivere signore lettera   ...
# padre madre moglie         ...
# cielo occhio dolce         ...
# teatro musica opera        ...
# andare orare mondo         ...
# chiesa città ordine        ...
# banco ducati soldi         ...
# terra nazione agricoltura  ...
# foglio pubblico città      ...
#
#                            1822_Lo-Spettatore-italiano_Giovanni-Ferri-di-S.-Costante_Vol-4_Nr-70_117-1148_0001  \
# morale stile poesia                                                   0.0098
# donna donne parlare                                                   0.0017
# virtù natura cuore                                                    0.3018
# ant pietro marco                                                      0.0004
# acqua medico corpo                                                    0.0006
# andare casa mano                                                      0.0018
# credere virtù ragione                                                 0.0592
# duc casa pago                                                         0.0005
# colore bianco moda                                                    0.0003
# bar oglio bal                                                         0.0002
# scrivere opera autore                                                 0.0022
# ritrovare maniera mondo                                               0.0009
# taglio laudo delli                                                    0.0005
# scrivere signore lettera                                              0.0005
# padre madre moglie                                                    0.3204
# cielo occhio dolce                                                    0.0376
# teatro musica opera                                                   0.0007
# andare orare mondo                                                    0.2021
# chiesa città ordine                                                   0.0556
# banco ducati soldi                                                    0.0002
# terra nazione agricoltura                                             0.0011
# foglio pubblico città                                                 0.0019
#
#                            1822_Lo-Spettatore-italiano_Giovanni-Ferri-di-S.-Costante_Vol-4_Nr-71_117-1149_0000  \
# morale stile poesia                                                   0.0003
# donna donne parlare                                                   0.0007
# virtù natura cuore                                                    0.1046
# ant pietro marco                                                      0.0002
# acqua medico corpo                                                    0.0003
# andare casa mano                                                      0.0488
# credere virtù ragione                                                 0.1542
# duc casa pago                                                         0.0002
# colore bianco moda                                                    0.0001
# bar oglio bal                                                         0.0001
# scrivere opera autore                                                 0.0050
# ritrovare maniera mondo                                               0.0004
# taglio laudo delli                                                    0.0002
# scrivere signore lettera                                              0.0002
# padre madre moglie                                                    0.3610
# cielo occhio dolce                                                    0.1167
# teatro musica opera                                                   0.0003
# andare orare mondo                                                    0.0727
# chiesa città ordine                                                   0.1045
# banco ducati soldi                                                    0.0001
# terra nazione agricoltura                                             0.0285
# foglio pubblico città                                                 0.0008
#
#                            1822_Lo-Spettatore-italiano_Giovanni-Ferri-di-S.-Costante_Vol-4_Nr-72_117-1150_0000  \
# morale stile poesia                                                   0.0003
# donna donne parlare                                                   0.0751
# virtù natura cuore                                                    0.1939
# ant pietro marco                                                      0.0002
# acqua medico corpo                                                    0.0003
# andare casa mano                                                      0.0044
# credere virtù ragione                                                 0.1470
# duc casa pago                                                         0.0002
# colore bianco moda                                                    0.0039
# bar oglio bal                                                         0.0001
# scrivere opera autore                                                 0.0307
# ritrovare maniera mondo                                               0.0004
# taglio laudo delli                                                    0.0002
# scrivere signore lettera                                              0.0002
# padre madre moglie                                                    0.1643
# cielo occhio dolce                                                    0.2573
# teatro musica opera                                                   0.0003
# andare orare mondo                                                    0.0006
# chiesa città ordine                                                   0.0004
# banco ducati soldi                                                    0.0150
# terra nazione agricoltura                                             0.1009
# foglio pubblico città                                                 0.0045
#
#                            1822_Lo-Spettatore-italiano_Giovanni-Ferri-di-S.-Costante_Vol-4_Nr-72_117-1150_0001  \
# morale stile poesia                                                   0.0007
# donna donne parlare                                                   0.0017
# virtù natura cuore                                                    0.1791
# ant pietro marco                                                      0.0004
# acqua medico corpo                                                    0.0007
# andare casa mano                                                      0.0018
# credere virtù ragione                                                 0.0421
# duc casa pago                                                         0.0005
# colore bianco moda                                                    0.0003
# bar oglio bal                                                         0.0002
# scrivere opera autore                                                 0.0866
# ritrovare maniera mondo                                               0.0010
# taglio laudo delli                                                    0.0005
# scrivere signore lettera                                              0.0005
# padre madre moglie                                                    0.2450
# cielo occhio dolce                                                    0.1980
# teatro musica opera                                                   0.0007
# andare orare mondo                                                    0.0484
# chiesa città ordine                                                   0.0009
# banco ducati soldi                                                    0.0002
# terra nazione agricoltura                                             0.1886
# foglio pubblico città                                                 0.0019
#
#                            1822_Lo-Spettatore-italiano_Giovanni-Ferri-di-S.-Costante_Vol-4_Nr-73_117-1151_0000  \
# morale stile poesia                                                   0.0003
# donna donne parlare                                                   0.0009
# virtù natura cuore                                                    0.1830
# ant pietro marco                                                      0.0002
# acqua medico corpo                                                    0.0284
# andare casa mano                                                      0.1553
# credere virtù ragione                                                 0.1427
# duc casa pago                                                         0.0002
# colore bianco moda                                                    0.0002
# bar oglio bal                                                         0.0001
# scrivere opera autore                                                 0.0011
# ritrovare maniera mondo                                               0.0005
# taglio laudo delli                                                    0.0003
# scrivere signore lettera                                              0.0003
# padre madre moglie                                                    0.2440
# cielo occhio dolce                                                    0.1691
# teatro musica opera                                                   0.0004
# andare orare mondo                                                    0.0710
# chiesa città ordine                                                   0.0004
# banco ducati soldi                                                    0.0001
# terra nazione agricoltura                                             0.0006
# foglio pubblico città                                                 0.0010
#
#                            1822_Lo-Spettatore-italiano_Giovanni-Ferri-di-S.-Costante_Vol-4_Nr-74_117-1152_0000  \
# morale stile poesia                                                   0.0005
# donna donne parlare                                                   0.0230
# virtù natura cuore                                                    0.1955
# ant pietro marco                                                      0.0003
# acqua medico corpo                                                    0.0005
# andare casa mano                                                      0.0807
# credere virtù ragione                                                 0.0829
# duc casa pago                                                         0.0004
# colore bianco moda                                                    0.0003
# bar oglio bal                                                         0.0002
# scrivere opera autore                                                 0.1171
# ritrovare maniera mondo                                               0.0007
# taglio laudo delli                                                    0.0004
# scrivere signore lettera                                              0.0004
# padre madre moglie                                                    0.3038
# cielo occhio dolce                                                    0.1812
# teatro musica opera                                                   0.0006
# andare orare mondo                                                    0.0012
# chiesa città ordine                                                   0.0007
# banco ducati soldi                                                    0.0002
# terra nazione agricoltura                                             0.0008
# foglio pubblico città                                                 0.0087
#
#                            1822_Lo-Spettatore-italiano_Giovanni-Ferri-di-S.-Costante_Vol-4_Nr-75_117-1153_0000  \
# morale stile poesia                                                   0.0003
# donna donne parlare                                                   0.0009
# virtù natura cuore                                                    0.3079
# ant pietro marco                                                      0.0002
# acqua medico corpo                                                    0.0003
# andare casa mano                                                      0.0289
# credere virtù ragione                                                 0.1979
# duc casa pago                                                         0.0096
# colore bianco moda                                                    0.0002
# bar oglio bal                                                         0.0001
# scrivere opera autore                                                 0.0477
# ritrovare maniera mondo                                               0.0051
# taglio laudo delli                                                    0.0003
# scrivere signore lettera                                              0.0003
# padre madre moglie                                                    0.0659
# cielo occhio dolce                                                    0.1170
# teatro musica opera                                                   0.0237
# andare orare mondo                                                    0.1917
# chiesa città ordine                                                   0.0004
# banco ducati soldi                                                    0.0001
# terra nazione agricoltura                                             0.0005
# foglio pubblico città                                                 0.0010
#
#                            1822_Lo-Spettatore-italiano_Giovanni-Ferri-di-S.-Costante_Vol-4_Nr-75_117-1153_0001  \
# morale stile poesia                                                   0.0006
# donna donne parlare                                                   0.0015
# virtù natura cuore                                                    0.1418
# ant pietro marco                                                      0.0003
# acqua medico corpo                                                    0.0006
# andare casa mano                                                      0.0015
# credere virtù ragione                                                 0.2232
# duc casa pago                                                         0.0004
# colore bianco moda                                                    0.0629
# bar oglio bal                                                         0.0002
# scrivere opera autore                                                 0.0019
# ritrovare maniera mondo                                               0.0008
# taglio laudo delli                                                    0.0004
# scrivere signore lettera                                              0.0161
# padre madre moglie                                                    0.1421
# cielo occhio dolce                                                    0.2046
# teatro musica opera                                                   0.0006
# andare orare mondo                                                    0.1658
# chiesa città ordine                                                   0.0321
# banco ducati soldi                                                    0.0002
# terra nazione agricoltura                                             0.0009
# foglio pubblico città                                                 0.0016
#
#                            1822_Lo-Spettatore-italiano_Giovanni-Ferri-di-S.-Costante_Vol-4_Nr-76_117-1154_0000  \
# morale stile poesia                                                   0.0002
# donna donne parlare                                                   0.0040
# virtù natura cuore                                                    0.2067
# ant pietro marco                                                      0.0779
# acqua medico corpo                                                    0.0002
# andare casa mano                                                      0.0717
# credere virtù ragione                                                 0.1978
# duc casa pago                                                         0.0002
# colore bianco moda                                                    0.0001
# bar oglio bal                                                         0.0001
# scrivere opera autore                                                 0.0143
# ritrovare maniera mondo                                               0.0003
# taglio laudo delli                                                    0.0002
# scrivere signore lettera                                              0.0239
# padre madre moglie                                                    0.1493
# cielo occhio dolce                                                    0.1391
# teatro musica opera                                                   0.0003
# andare orare mondo                                                    0.0276
# chiesa città ordine                                                   0.0003
# banco ducati soldi                                                    0.0136
# terra nazione agricoltura                                             0.0680
# foglio pubblico città                                                 0.0041
#
#                            1822_Lo-Spettatore-italiano_Giovanni-Ferri-di-S.-Costante_Vol-4_Nr-77_117-1155_0000
# morale stile poesia                                                   0.0003
# donna donne parlare                                                   0.0007
# virtù natura cuore                                                    0.4457
# ant pietro marco                                                      0.0001
# acqua medico corpo                                                    0.0145
# andare casa mano                                                      0.0613
# credere virtù ragione                                                 0.0730
# duc casa pago                                                         0.0002
# colore bianco moda                                                    0.0144
# bar oglio bal                                                         0.0001
# scrivere opera autore                                                 0.0864
# ritrovare maniera mondo                                               0.0004
# taglio laudo delli                                                    0.0002
# scrivere signore lettera                                              0.0002
# padre madre moglie                                                    0.0539
# cielo occhio dolce                                                    0.1109
# teatro musica opera                                                   0.0003
# andare orare mondo                                                    0.0148
# chiesa città ordine                                                   0.0894
# banco ducati soldi                                                    0.0286
# terra nazione agricoltura                                             0.0040
# foglio pubblico città                                                 0.0007
#
# [22 rows x 5363 columns]
